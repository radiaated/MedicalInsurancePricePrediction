# %%
import pandas as pd

df = pd.read_csv("./medidatasett.csv")
df
# Out:
#             age     sex        bmi  children smoker     region  \
# 0     19.000000  female  27.900000       0.0    yes  southwest
# 1     18.000000    male  33.770000       1.0     no  southeast
# 2     28.000000    male  33.000000       3.0     no  southeast
# 3     33.000000    male  22.705000       0.0     no  northwest
# 4     32.000000    male  28.880000       0.0     no  northwest
# ...         ...     ...        ...       ...    ...        ...
# 6897  46.913222    male  30.057785       3.0    yes  southwest
# 6898  43.603648  female  27.369983       1.0     no  southwest
# 6899  56.028230  female  25.696587       0.0     no  northwest
# 6900  48.119259    male  27.898078       1.0    yes  southwest
# 6901  46.848468  female  45.466556       1.0     no  southeast
#
#           medical_history family_medical_history    occupation       charges
# 0                      No          Heart Disease       Student  16884.924000
# ...

# %%
df["age"] = df["age"].astype(int)
df["bmi"] = df["bmi"].astype(float).round(2)
df["children"] = df["age"].astype(int)

# %%
df
# Out:
#       age     sex    bmi  children smoker     region      medical_history  \
# 0      19  female  27.90        19    yes  southwest                   No
# 1      18    male  33.77        18     no  southeast                   No
# 2      28    male  33.00        28     no  southeast  High Blood Pressure
# 3      33    male  22.70        33     no  northwest                   No
# 4      32    male  28.88        32     no  northwest        Heart Disease
# ...   ...     ...    ...       ...    ...        ...                  ...
# 6897   46    male  30.06        46    yes  southwest                   No
# 6898   43  female  27.37        43     no  southwest                   No
# 6899   56  female  25.70        56     no  northwest        Heart Disease
# 6900   48    male  27.90        48    yes  southwest                   No
# 6901   46  female  45.47        46     no  southeast        Heart Disease
#
#      family_medical_history    occupation       charges
# ...

# %%
df.to_csv("./medidataset2.csv", index=False)
